# %%
import cv2
import os

# Directory setup
directory = 'CNN_data_96x96/'
print(os.getcwd())

if not os.path.exists(directory):
    os.mkdir(directory)
if not os.path.exists(f'{directory}/blank'):
    os.mkdir(f'{directory}/blank')

for i in range(6):
    if not os.path.exists(f'{directory}/{i}'):
        os.mkdir(f'{directory}/{i}')

# Video capture
cap = cv2.VideoCapture(0)

while True:
    _, frame = cap.read()
    count = {
        '0': len(os.listdir(directory + "/0")),
        '1': len(os.listdir(directory + "/1")),
        '2': len(os.listdir(directory + "/2")),
        '3': len(os.listdir(directory + "/3")),
        '4': len(os.listdir(directory + "/4")),
        
        'blank': len(os.listdir(directory + "/blank"))
    }

    row = frame.shape[1]
    col = frame.shape[0]
    cv2.rectangle(frame, (0, 40), (300, 300), (255, 255, 255), 2)
    cv2.imshow("data", frame)
    frame = frame[40:300, 0:300]
    cv2.imshow("ROI", frame)
    frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    frame = cv2.resize(frame, (48,48))
    
    interrupt = cv2.waitKey(10)
    
    if interrupt & 0xFF == ord('0'):
        cv2.imwrite(os.path.join(directory, '0', f'{count["0"]}.jpg'), frame)
    if interrupt & 0xFF == ord('1'):
        cv2.imwrite(os.path.join(directory, '1', f'{count["1"]}.jpg'), frame)
    if interrupt & 0xFF == ord('2'):
        cv2.imwrite(os.path.join(directory, '2', f'{count["2"]}.jpg'), frame)
    if interrupt & 0xFF == ord('3'):
        cv2.imwrite(os.path.join(directory, '3', f'{count["3"]}.jpg'), frame)
    if interrupt & 0xFF == ord('4'):
        cv2.imwrite(os.path.join(directory, '4', f'{count["4"]}.jpg'), frame)
    if interrupt & 0xFF == ord('.'):
        cv2.imwrite(os.path.join(directory, 'blank', f'{count["blank"]}.jpg'), frame)
    
    if interrupt & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\Vinod Makkala\Desktop\ResearchProject

# %%
import os
import shutil
from keras.callbacks import TensorBoard
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Input, Conv2D, MaxPooling2D, Dropout, Flatten, Dense
import matplotlib.pyplot as plt

# Ensure reproducibility
import tensorflow as tf
import numpy as np
import random

np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# Remove the existing Logs directory if it exists
logdir = "Logs"
if os.path.exists(logdir):
    shutil.rmtree(logdir)

tensorboard_callback = TensorBoard(log_dir=logdir)

# Define the model
model = Sequential([
    Input(shape=(48, 48, 1)),
    Conv2D(128, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.4),

    Conv2D(256, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.4),

    Conv2D(512, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.4),

    Conv2D(512, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(pool_size=(2,2)),
    Dropout(0.4),

    Flatten(),

    Dense(512, activation='relu'),
    Dropout(0.4),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.3),

    Dense(6, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Image data generators
train_datagen = ImageDataGenerator(rescale=1./255)
val_datagen = ImageDataGenerator(rescale=1./255)

batch_size = 64

train_generator = train_datagen.flow_from_directory(
    './splitdataset48x48/train',
    target_size=(48, 48),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale'
)

validation_generator = val_datagen.flow_from_directory(
    './splitdataset48x48/val',
    target_size=(48, 48),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale'
)

# Training the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=100,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[tensorboard_callback]
)

# Plotting the training and validation accuracy and loss
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')

plt.show()
# Out:
# Found 1151 images belonging to 6 classes.
# Found 290 images belonging to 6 classes.
# Epoch 1/100
# D:\Anaconda\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.2010 - loss: 1.7916 - val_accuracy: 0.2070 - val_loss: 1.7868
# Epoch 2/100
#  1/17 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.2188 - loss: 1.7746
# D:\Anaconda\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - accuracy: 0.2188 - loss: 1.7746 - val_accuracy: 0.1471 - val_loss: 1.7849
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.1978 - loss: 1.7810 - val_accuracy: 0.2148 - val_loss: 1.7345
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.2031 - loss: 1.7350 - val_accuracy: 0.0882 - val_loss: 1.7819
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 80s 2s/step - accuracy: 0.2074 - loss: 1.6846 - val_accuracy: 0.4258 - val_loss: 1.6187
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 348ms/step - accuracy: 0.3594 - loss: 1.5938 - val_accuracy: 0.5000 - val_loss: 1.4921
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 71s 2s/step - accuracy: 0.3334 - loss: 1.5165 - val_accuracy: 0.4023 - val_loss: 1.4610
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.3906 - loss: 1.4065 - val_accuracy: 0.3235 - val_loss: 1.4709
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.3875 - loss: 1.4703 - val_accuracy: 0.3867 - val_loss: 1.3288
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.3594 - loss: 1.3157 - val_accuracy: 0.3824 - val_loss: 1.2345
# Epoch 11/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 548ms/step - accuracy: 0.3650 - loss: 1.3953 - val_accuracy: 0.4102 - val_loss: 1.2763
# Epoch 12/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.5156 - loss: 1.2071 - val_accuracy: 0.4706 - val_loss: 1.2888
# Epoch 13/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 499ms/step - accuracy: 0.4192 - loss: 1.2504 - val_accuracy: 0.4648 - val_loss: 1.2209
# Epoch 14/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5156 - loss: 1.1715 - val_accuracy: 0.5000 - val_loss: 1.1617
# Epoch 15/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 519ms/step - accuracy: 0.4852 - loss: 1.0885 - val_accuracy: 0.3711 - val_loss: 1.3426
# Epoch 16/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.5781 - loss: 1.1339 - val_accuracy: 0.4412 - val_loss: 1.2880
# Epoch 17/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 507ms/step - accuracy: 0.5831 - loss: 1.0125 - val_accuracy: 0.6875 - val_loss: 0.9179
# Epoch 18/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.6719 - loss: 0.8997 - val_accuracy: 0.7059 - val_loss: 0.7949
# Epoch 19/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 558ms/step - accuracy: 0.7011 - loss: 0.8100 - val_accuracy: 0.7031 - val_loss: 0.7642
# Epoch 20/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.7302 - loss: 0.7029 - val_accuracy: 0.8235 - val_loss: 0.5155
# Epoch 21/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 35s 2s/step - accuracy: 0.7101 - loss: 0.6458 - val_accuracy: 0.7891 - val_loss: 0.4684
# Epoch 22/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 312ms/step - accuracy: 0.7188 - loss: 0.5203 - val_accuracy: 0.8824 - val_loss: 0.4981
# Epoch 23/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.7570 - loss: 0.5481 - val_accuracy: 0.7578 - val_loss: 0.4620
# Epoch 24/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6875 - loss: 1.0075 - val_accuracy: 0.6471 - val_loss: 0.6061
# Epoch 25/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - accuracy: 0.7640 - loss: 0.5984 - val_accuracy: 0.8242 - val_loss: 0.3814
# Epoch 26/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 284ms/step - accuracy: 0.8281 - loss: 0.4307 - val_accuracy: 0.8235 - val_loss: 0.4233
# Epoch 27/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 73s 2s/step - accuracy: 0.7922 - loss: 0.4461 - val_accuracy: 0.8320 - val_loss: 0.3424
# Epoch 28/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.7812 - loss: 0.3931 - val_accuracy: 0.9118 - val_loss: 0.2121
# Epoch 29/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.8217 - loss: 0.4269 - val_accuracy: 0.8594 - val_loss: 0.3426
# Epoch 30/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.8750 - loss: 0.2751 - val_accuracy: 0.8235 - val_loss: 0.4108
# Epoch 31/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.8376 - loss: 0.3340 - val_accuracy: 0.9219 - val_loss: 0.2602
# Epoch 32/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.8125 - loss: 0.4916 - val_accuracy: 0.8824 - val_loss: 0.2312
# Epoch 33/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8643 - loss: 0.3317 - val_accuracy: 0.9062 - val_loss: 0.2651
# Epoch 34/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9219 - loss: 0.2979 - val_accuracy: 0.9412 - val_loss: 0.1767
# Epoch 35/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 77s 2s/step - accuracy: 0.8849 - loss: 0.2784 - val_accuracy: 0.9414 - val_loss: 0.2345
# Epoch 36/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - accuracy: 0.9062 - loss: 0.3681 - val_accuracy: 0.9706 - val_loss: 0.1381
# Epoch 37/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 48s 3s/step - accuracy: 0.9254 - loss: 0.2504 - val_accuracy: 0.9336 - val_loss: 0.2187
# Epoch 38/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.9531 - loss: 0.1904 - val_accuracy: 0.9118 - val_loss: 0.2933
# Epoch 39/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 44s 3s/step - accuracy: 0.9467 - loss: 0.2332 - val_accuracy: 0.9688 - val_loss: 0.1030
# Epoch 40/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9531 - loss: 0.1333 - val_accuracy: 1.0000 - val_loss: 0.0187
# Epoch 41/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.9804 - loss: 0.0843 - val_accuracy: 0.9688 - val_loss: 0.0765
# Epoch 42/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9531 - loss: 0.0774 - val_accuracy: 0.9706 - val_loss: 0.0996
# Epoch 43/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9751 - loss: 0.1072 - val_accuracy: 0.9648 - val_loss: 0.1204
# Epoch 44/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9844 - loss: 0.0435 - val_accuracy: 0.9706 - val_loss: 0.0587
# Epoch 45/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9818 - loss: 0.0648 - val_accuracy: 0.9805 - val_loss: 0.0538
# Epoch 46/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.9375 - loss: 0.1205 - val_accuracy: 0.9706 - val_loss: 0.1339
# Epoch 47/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step - accuracy: 0.9580 - loss: 0.1519 - val_accuracy: 0.9648 - val_loss: 0.1785
# Epoch 48/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9688 - loss: 0.0805 - val_accuracy: 0.9412 - val_loss: 0.5697
# Epoch 49/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 29s 2s/step - accuracy: 0.9505 - loss: 0.1977 - val_accuracy: 0.9375 - val_loss: 0.2316
# Epoch 50/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9531 - loss: 0.1782 - val_accuracy: 0.9412 - val_loss: 0.3986
# Epoch 51/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 502ms/step - accuracy: 0.9480 - loss: 0.1739 - val_accuracy: 0.9766 - val_loss: 0.0777
# Epoch 52/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9844 - loss: 0.1126 - val_accuracy: 0.9412 - val_loss: 0.1447
# Epoch 53/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 492ms/step - accuracy: 0.9917 - loss: 0.0516 - val_accuracy: 0.9766 - val_loss: 0.1067
# Epoch 54/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9688 - loss: 0.1536 - val_accuracy: 1.0000 - val_loss: 0.0134
# Epoch 55/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 510ms/step - accuracy: 0.9821 - loss: 0.0615 - val_accuracy: 0.9648 - val_loss: 0.1566
# Epoch 56/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9844 - loss: 0.0338 - val_accuracy: 1.0000 - val_loss: 0.0256
# Epoch 57/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 571ms/step - accuracy: 0.9840 - loss: 0.0735 - val_accuracy: 0.9727 - val_loss: 0.1104
# Epoch 58/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 1.0000 - loss: 0.0223 - val_accuracy: 0.9706 - val_loss: 0.0502
# Epoch 59/100
#  5/17 ━━━━━━━━━━━━━━━━━━━━ 6s 572ms/step - accuracy: 0.9717 - loss: 0.0821
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 85
#      76 validation_generator = val_datagen.flow_from_directory(
#      77     './splitdataset48x48/val',
#      78     target_size=(48, 48),
#    (...)
#      81     color_mode='grayscale'
#      82 )
#      84 # Training the model
# ---> 85 history = model.fit(
#      86     train_generator,
#      87     steps_per_epoch=train_generator.samples // batch_size,
#      88     epochs=100,
#      89     validation_data=validation_generator,
#      90     validation_steps=validation_generator.samples // batch_size,
#      91     callbacks=[tensorboard_callback]
#      92 )
#      94 # Plotting the training and validation accuracy and loss
#      95 acc = history.history['accuracy']
#
# File D:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\Anaconda\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:314, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     312 for step, iterator in epoch_iterator.enumerate_epoch():
#     313     callbacks.on_train_batch_begin(step)
# --> 314     logs = self.train_function(iterator)
#     315     logs = self._pythonify_logs(logs)
#     316     callbacks.on_train_batch_end(step, logs)
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File D:\Anaconda\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 model.save("/my_model.h5")
#
# File D:\Anaconda\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File D:\Anaconda\Lib\site-packages\h5py\_hl\files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File D:\Anaconda\Lib\site-packages\h5py\_hl\files.py:241, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     239     fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     240 elif mode == 'w':
# --> 241     fid = h5f.create(name, h5f.ACC_TRUNC, fapl=fapl, fcpl=fcpl)
#     242 elif mode == 'a':
#     243     # Open in append mode (read/write).
#     244     # If that fails, create a new file only if it won't clobber an
#     245     # existing one (ACC_EXCL)
#     246     try:
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\\h5f.pyx:122, in h5py.h5f.create()
#
# PermissionError: [Errno 13] Unable to synchronously create file (unable to open file: name = '/my_model.h5', errno = 13, error message = 'Permission denied', flags = 13, o_flags = 302)

# %%
import json
from tensorflow.keras.models import model_from_json

# Assuming 'model' is already defined and compiled
model_json = model.to_json()
with open("./my_model.json", 'w') as json_file:
    json_file.write(model_json)

# Use a relative path or a more specific path to save the model
model.save("./my_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard
import os
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 from keras.models import Sequential
#       3 from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
# ----> 4 from keras.preprocessing.image import ImageDataGenerator
#       5 from keras.callbacks import TensorBoard
#       6 import os
#
# ImportError: cannot import name 'ImageDataGenerator' from 'keras.preprocessing.image' (D:\Anaconda\Lib\site-packages\keras\api\preprocessing\image\__init__.py)

# %%
pip install tensorflow opencv-contrib-python split-folders
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.16.1-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: opencv-contrib-python in d:\anaconda\lib\site-packages (4.10.0.82)
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting tensorflow-intel==2.16.1 (from tensorflow)
#   Downloading tensorflow_intel-2.16.1-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: absl-py>=1.0.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.1.0)
# Collecting astunparse>=1.6.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: flatbuffers>=23.5.26 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (24.3.25)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading gast-0.5.4-py3-none-any.whl.metadata (1.3 kB)
# Collecting google-pasta>=0.1.1 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting h5py>=3.10.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading h5py-3.11.0-cp311-cp311-win_amd64.whl.metadata (2.5 kB)
# Collecting libclang>=13.0.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting ml-dtypes~=0.3.1 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading ml_dtypes-0.3.2-cp311-cp311-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: opt-einsum>=2.3.2 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in d:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (23.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (2.31.0)
# Requirement already satisfied: setuptools in d:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (68.2.2)
# Requirement already satisfied: six>=1.12.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.16.0)
# Collecting termcolor>=1.1.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading termcolor-2.4.0-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: typing-extensions>=3.6.6 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt>=1.11.0 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.14.1)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading grpcio-1.64.1-cp311-cp311-win_amd64.whl.metadata (3.4 kB)
# Collecting tensorboard<2.17,>=2.16 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting keras>=3.0.0 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading keras-3.3.3-py3-none-any.whl.metadata (5.7 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1 (from tensorflow-intel==2.16.1->tensorflow)
#   Downloading tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in d:\anaconda\lib\site-packages (from tensorflow-intel==2.16.1->tensorflow) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in d:\anaconda\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.16.1->tensorflow) (0.41.2)
# Requirement already satisfied: rich in d:\anaconda\lib\site-packages (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (13.3.5)
# Collecting namex (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow)
#   Downloading namex-0.0.8-py3-none-any.whl.metadata (246 bytes)
# Collecting optree (from keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow)
#   Downloading optree-0.11.0-cp311-cp311-win_amd64.whl.metadata (46 kB)
#      ---------------------------------------- 0.0/46.2 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/46.2 kB ? eta -:--:--
#      -------------------------------------- 46.2/46.2 kB 782.0 kB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.16.1->tensorflow) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in d:\anaconda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (3.4.1)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow)
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in d:\anaconda\lib\site-packages (from tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.2.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in d:\anaconda\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow-intel==2.16.1->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in d:\anaconda\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\anaconda\lib\site-packages (from rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in d:\anaconda\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->keras>=3.0.0->tensorflow-intel==2.16.1->tensorflow) (0.1.0)
# Downloading tensorflow-2.16.1-cp311-cp311-win_amd64.whl (2.1 kB)
# Downloading tensorflow_intel-2.16.1-cp311-cp311-win_amd64.whl (377.0 MB)
#    ---------------------------------------- 0.0/377.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/377.0 MB 991.0 kB/s eta 0:06:21
#    ---------------------------------------- 0.1/377.0 MB 1.4 MB/s eta 0:04:21
#    ---------------------------------------- 0.3/377.0 MB 1.9 MB/s eta 0:03:19
#    ---------------------------------------- 0.3/377.0 MB 2.2 MB/s eta 0:02:52
#    ---------------------------------------- 0.6/377.0 MB 2.8 MB/s eta 0:02:16
#    ---------------------------------------- 0.6/377.0 MB 2.7 MB/s eta 0:02:19
#    ---------------------------------------- 0.7/377.0 MB 2.2 MB/s eta 0:02:49
#    ---------------------------------------- 0.9/377.0 MB 2.5 MB/s eta 0:02:29
#    ---------------------------------------- 1.1/377.0 MB 2.7 MB/s eta 0:02:17
#    ---------------------------------------- 1.3/377.0 MB 2.9 MB/s eta 0:02:11
#    ---------------------------------------- 1.4/377.0 MB 3.0 MB/s eta 0:02:08
#    ---------------------------------------- 1.6/377.0 MB 2.9 MB/s eta 0:02:11
#    ---------------------------------------- 1.8/377.0 MB 2.9 MB/s eta 0:02:08
#    ---------------------------------------- 1.8/377.0 MB 2.8 MB/s eta 0:02:16
#    ---------------------------------------- 2.0/377.0 MB 2.8 MB/s eta 0:02:12
#    ---------------------------------------- 2.0/377.0 MB 2.7 MB/s eta 0:02:17
#    ---------------------------------------- 2.3/377.0 MB 2.8 MB/s eta 0:02:12
#    ---------------------------------------- 2.4/377.0 MB 2.9 MB/s eta 0:02:09
#    ---------------------------------------- 2.4/377.0 MB 2.9 MB/s eta 0:02:09
#    ---------------------------------------- 2.5/377.0 MB 2.8 MB/s eta 0:02:15
#    ---------------------------------------- 2.6/377.0 MB 2.7 MB/s eta 0:02:20
#    ---------------------------------------- 2.8/377.0 MB 2.7 MB/s eta 0:02:19
#    ---------------------------------------- 3.0/377.0 MB 2.8 MB/s eta 0:02:16
#    ---------------------------------------- 3.2/377.0 MB 2.8 MB/s eta 0:02:13
#    ---------------------------------------- 3.3/377.0 MB 2.8 MB/s eta 0:02:13
#    ---------------------------------------- 3.4/377.0 MB 2.8 MB/s eta 0:02:15
#    ---------------------------------------- 3.5/377.0 MB 2.8 MB/s eta 0:02:13
#    ---------------------------------------- 3.8/377.0 MB 2.9 MB/s eta 0:02:10
#    ---------------------------------------- 3.8/377.0 MB 2.8 MB/s eta 0:02:14
#    ---------------------------------------- 4.0/377.0 MB 2.8 MB/s eta 0:02:14
#    ---------------------------------------- 4.2/377.0 MB 2.9 MB/s eta 0:02:11
#    ---------------------------------------- 4.4/377.0 MB 2.9 MB/s eta 0:02:07
#    ---------------------------------------- 4.6/377.0 MB 3.0 MB/s eta 0:02:05
#     --------------------------------------- 4.7/377.0 MB 2.9 MB/s eta 0:02:07
#     --------------------------------------- 4.9/377.0 MB 2.9 MB/s eta 0:02:07
#     --------------------------------------- 5.1/377.0 MB 3.0 MB/s eta 0:02:05
#     --------------------------------------- 5.2/377.0 MB 3.0 MB/s eta 0:02:06
#     --------------------------------------- 5.2/377.0 MB 2.9 MB/s eta 0:02:07
#     --------------------------------------- 5.2/377.0 MB 2.9 MB/s eta 0:02:07
#     --------------------------------------- 5.2/377.0 MB 2.9 MB/s eta 0:02:07
#     --------------------------------------- 5.2/377.0 MB 2.9 MB/s eta 0:02:07
#     --------------------------------------- 5.7/377.0 MB 2.9 MB/s eta 0:02:11
#     --------------------------------------- 5.8/377.0 MB 2.9 MB/s eta 0:02:09
#     --------------------------------------- 6.0/377.0 MB 2.9 MB/s eta 0:02:10
#     --------------------------------------- 6.1/377.0 MB 2.9 MB/s eta 0:02:10
#     --------------------------------------- 6.2/377.0 MB 2.8 MB/s eta 0:02:12
#     --------------------------------------- 6.4/377.0 MB 2.9 MB/s eta 0:02:09
#     --------------------------------------- 6.6/377.0 MB 2.9 MB/s eta 0:02:09
#     --------------------------------------- 6.8/377.0 MB 2.9 MB/s eta 0:02:07
#     --------------------------------------- 7.0/377.0 MB 3.0 MB/s eta 0:02:05
#     --------------------------------------- 7.1/377.0 MB 3.0 MB/s eta 0:02:05
#     --------------------------------------- 7.3/377.0 MB 3.0 MB/s eta 0:02:04
#     --------------------------------------- 7.5/377.0 MB 3.0 MB/s eta 0:02:04
#     --------------------------------------- 7.6/377.0 MB 3.0 MB/s eta 0:02:04
#     --------------------------------------- 7.9/377.0 MB 3.0 MB/s eta 0:02:03
#     --------------------------------------- 8.0/377.0 MB 3.0 MB/s eta 0:02:03
#     --------------------------------------- 8.3/377.0 MB 3.1 MB/s eta 0:02:01
#     --------------------------------------- 8.4/377.0 MB 3.1 MB/s eta 0:02:01
#     --------------------------------------- 8.7/377.0 MB 3.1 MB/s eta 0:01:59
#     --------------------------------------- 8.8/377.0 MB 3.1 MB/s eta 0:01:58
#     --------------------------------------- 8.8/377.0 MB 3.1 MB/s eta 0:01:59
#     --------------------------------------- 9.2/377.0 MB 3.1 MB/s eta 0:01:58
#     --------------------------------------- 9.3/377.0 MB 3.1 MB/s eta 0:01:58
#    - -------------------------------------- 9.4/377.0 MB 3.1 MB/s eta 0:01:58
#    - -------------------------------------- 9.4/377.0 MB 3.1 MB/s eta 0:01:58
#    - -------------------------------------- 9.4/377.0 MB 3.1 MB/s eta 0:01:58
#    - -------------------------------------- 9.5/377.0 MB 3.0 MB/s eta 0:02:04
#    - -------------------------------------- 10.0/377.0 MB 3.1 MB/s eta 0:01:58
#    - -------------------------------------- 10.2/377.0 MB 3.1 MB/s eta 0:01:59
#    - -------------------------------------- 10.4/377.0 MB 3.1 MB/s eta 0:01:57
#    - -------------------------------------- 10.5/377.0 MB 3.2 MB/s eta 0:01:56
#    - -------------------------------------- 10.6/377.0 MB 3.2 MB/s eta 0:01:56
#    - -------------------------------------- 10.8/377.0 MB 3.1 MB/s eta 0:01:57
#    - -------------------------------------- 10.9/377.0 MB 3.1 MB/s eta 0:01:57
#    - -------------------------------------- 10.9/377.0 MB 3.2 MB/s eta 0:01:56
#    - -------------------------------------- 11.1/377.0 MB 3.2 MB/s eta 0:01:56
#    - -------------------------------------- 11.3/377.0 MB 3.1 MB/s eta 0:01:57
#    - -------------------------------------- 11.3/377.0 MB 3.1 MB/s eta 0:01:57
#    - -------------------------------------- 11.3/377.0 MB 3.1 MB/s eta 0:01:57
#    - -------------------------------------- 11.3/377.0 MB 3.1 MB/s eta 0:01:57
#    - -------------------------------------- 11.9/377.0 MB 3.1 MB/s eta 0:01:58
#    - -------------------------------------- 11.9/377.0 MB 3.1 MB/s eta 0:01:58
#    - -------------------------------------- 11.9/377.0 MB 3.1 MB/s eta 0:01:58
#    - -------------------------------------- 12.0/377.0 MB 3.1 MB/s eta 0:02:00
#    - -------------------------------------- 12.1/377.0 MB 3.1 MB/s eta 0:02:00
#    - -------------------------------------- 12.1/377.0 MB 3.1 MB/s eta 0:02:00
#    - -------------------------------------- 12.1/377.0 MB 3.1 MB/s eta 0:02:00
#    - -------------------------------------- 12.5/377.0 MB 3.0 MB/s eta 0:02:01
#    - -------------------------------------- 12.7/377.0 MB 3.0 MB/s eta 0:02:01
#    - -------------------------------------- 12.7/377.0 MB 3.1 MB/s eta 0:02:00
#    - -------------------------------------- 12.8/377.0 MB 3.1 MB/s eta 0:01:59
#    - -------------------------------------- 12.9/377.0 MB 3.1 MB/s eta 0:01:59
#    - -------------------------------------- 13.0/377.0 MB 3.0 MB/s eta 0:02:01
#    - -------------------------------------- 13.0/377.0 MB 3.0 MB/s eta 0:02:01
#    - -------------------------------------- 13.1/377.0 MB 3.0 MB/s eta 0:02:03
#    - -------------------------------------- 13.2/377.0 MB 2.9 MB/s eta 0:02:04
#    - -------------------------------------- 13.3/377.0 MB 2.9 MB/s eta 0:02:04
#    - -------------------------------------- 13.5/377.0 MB 2.9 MB/s eta 0:02:05
#    - -------------------------------------- 13.6/377.0 MB 2.9 MB/s eta 0:02:04
#    - -------------------------------------- 13.7/377.0 MB 2.9 MB/s eta 0:02:05
#    - -------------------------------------- 13.9/377.0 MB 2.9 MB/s eta 0:02:05
#    - -------------------------------------- 14.0/377.0 MB 2.9 MB/s eta 0:02:06
#    - -------------------------------------- 14.2/377.0 MB 2.9 MB/s eta 0:02:05
#    - -------------------------------------- 14.3/377.0 MB 2.9 MB/s eta 0:02:05
#    - -------------------------------------- 14.4/377.0 MB 2.9 MB/s eta 0:02:05
#    - -------------------------------------- 14.6/377.0 MB 2.9 MB/s eta 0:02:06
#    - -------------------------------------- 14.7/377.0 MB 2.9 MB/s eta 0:02:07
#    - -------------------------------------- 14.7/377.0 MB 2.8 MB/s eta 0:02:08
#    - -------------------------------------- 14.7/377.0 MB 2.8 MB/s eta 0:02:08
#    - -------------------------------------- 15.0/377.0 MB 2.8 MB/s eta 0:02:08
#    - -------------------------------------- 15.2/377.0 MB 2.8 MB/s eta 0:02:08
#    - -------------------------------------- 15.2/377.0 MB 2.8 MB/s eta 0:02:08
#    - -------------------------------------- 15.2/377.0 MB 2.8 MB/s eta 0:02:08
#    - -------------------------------------- 15.2/377.0 MB 2.8 MB/s eta 0:02:08
#    - -------------------------------------- 15.7/377.0 MB 2.9 MB/s eta 0:02:04
#    - -------------------------------------- 15.7/377.0 MB 2.9 MB/s eta 0:02:05
#    - -------------------------------------- 15.9/377.0 MB 2.9 MB/s eta 0:02:07
#    - -------------------------------------- 16.0/377.0 MB 2.8 MB/s eta 0:02:08
#    - -------------------------------------- 16.2/377.0 MB 2.9 MB/s eta 0:02:06
#    - -------------------------------------- 16.2/377.0 MB 2.9 MB/s eta 0:02:07
#    - -------------------------------------- 16.3/377.0 MB 2.8 MB/s eta 0:02:10
#    - -------------------------------------- 16.4/377.0 MB 2.8 MB/s eta 0:02:08
#    - -------------------------------------- 16.5/377.0 MB 2.8 MB/s eta 0:02:09
#    - -------------------------------------- 16.7/377.0 MB 2.8 MB/s eta 0:02:10
#    - -------------------------------------- 16.8/377.0 MB 2.8 MB/s eta 0:02:09
#    - -------------------------------------- 17.0/377.0 MB 2.8 MB/s eta 0:02:10
#    - -------------------------------------- 17.2/377.0 MB 2.8 MB/s eta 0:02:11
#    - -------------------------------------- 17.3/377.0 MB 2.8 MB/s eta 0:02:10
#    - -------------------------------------- 17.4/377.0 MB 2.7 MB/s eta 0:02:12
#    - -------------------------------------- 17.6/377.0 MB 2.8 MB/s eta 0:02:11
#    - -------------------------------------- 17.7/377.0 MB 2.8 MB/s eta 0:02:11
#    - -------------------------------------- 18.0/377.0 MB 2.8 MB/s eta 0:02:10
#    - -------------------------------------- 18.2/377.0 MB 2.8 MB/s eta 0:02:10
#    - -------------------------------------- 18.3/377.0 MB 2.8 MB/s eta 0:02:10
#    - -------------------------------------- 18.5/377.0 MB 2.8 MB/s eta 0:02:11
#    - -------------------------------------- 18.6/377.0 MB 2.7 MB/s eta 0:02:11
#    - -------------------------------------- 18.8/377.0 MB 2.7 MB/s eta 0:02:11
#    -- ------------------------------------- 18.9/377.0 MB 2.7 MB/s eta 0:02:12
#    -- ------------------------------------- 19.1/377.0 MB 2.8 MB/s eta 0:02:11
#    -- ------------------------------------- 19.2/377.0 MB 2.7 MB/s eta 0:02:12
#    -- ------------------------------------- 19.3/377.0 MB 2.7 MB/s eta 0:02:14
#    -- ------------------------------------- 19.6/377.0 MB 2.7 MB/s eta 0:02:12
#    -- ------------------------------------- 19.8/377.0 MB 2.8 MB/s eta 0:02:07
#    -- ------------------------------------- 19.9/377.0 MB 2.8 MB/s eta 0:02:08
#    -- ------------------------------------- 20.0/377.0 MB 2.8 MB/s eta 0:02:10
#    -- ------------------------------------- 20.2/377.0 MB 2.7 MB/s eta 0:02:11
#    -- ------------------------------------- 20.5/377.0 MB 2.8 MB/s eta 0:02:10
#    -- ------------------------------------- 20.7/377.0 MB 2.8 MB/s eta 0:02:09
#    -- ------------------------------------- 20.9/377.0 MB 2.8 MB/s eta 0:02:07
#    -- ------------------------------------- 21.0/377.0 MB 2.8 MB/s eta 0:02:07
#    -- ------------------------------------- 21.2/377.0 MB 2.8 MB/s eta 0:02:06
#    -- ------------------------------------- 21.4/377.0 MB 2.8 MB/s eta 0:02:06
#    -- ------------------------------------- 21.5/377.0 MB 2.8 MB/s eta 0:02:07
#    -- ------------------------------------- 21.7/377.0 MB 2.9 MB/s eta 0:02:03
#    -- ------------------------------------- 21.8/377.0 MB 2.9 MB/s eta 0:02:05
#    -- ------------------------------------- 22.0/377.0 MB 2.8 MB/s eta 0:02:06
#    -- ------------------------------------- 22.3/377.0 MB 2.9 MB/s eta 0:02:01
#    -- ------------------------------------- 22.4/377.0 MB 3.0 MB/s eta 0:01:57
#    -- ------------------------------------- 22.5/377.0 MB 3.0 MB/s eta 0:01:59
#    -- ------------------------------------- 22.7/377.0 MB 2.9 MB/s eta 0:02:01
#    -- ------------------------------------- 22.8/377.0 MB 2.9 MB/s eta 0:02:01
#    -- ------------------------------------- 23.0/377.0 MB 3.0 MB/s eta 0:01:59
#    -- ------------------------------------- 23.1/377.0 MB 3.0 MB/s eta 0:01:59
#    -- ------------------------------------- 23.3/377.0 MB 3.1 MB/s eta 0:01:56
#    -- ------------------------------------- 23.5/377.0 MB 3.1 MB/s eta 0:01:54
#    -- ------------------------------------- 23.7/377.0 MB 3.1 MB/s eta 0:01:53
#    -- ------------------------------------- 23.7/377.0 MB 3.1 MB/s eta 0:01:54
#    -- ------------------------------------- 23.7/377.0 MB 3.1 MB/s eta 0:01:54
#    -- ------------------------------------- 23.7/377.0 MB 3.1 MB/s eta 0:01:54
#    -- ------------------------------------- 23.7/377.0 MB 3.1 MB/s eta 0:01:54
#    -- ------------------------------------- 24.2/377.0 MB 3.1 MB/s eta 0:01:54
#    -- ------------------------------------- 24.3/377.0 MB 3.1 MB/s eta 0:01:55
#    -- ------------------------------------- 24.3/377.0 MB 3.1 MB/s eta 0:01:55
#    -- ------------------------------------- 24.4/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 24.5/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 24.6/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 24.7/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 24.8/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 24.8/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 24.8/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 24.8/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 24.8/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 25.0/377.0 MB 2.9 MB/s eta 0:02:03
#    -- ------------------------------------- 25.0/377.0 MB 2.9 MB/s eta 0:02:03
#    -- ------------------------------------- 25.0/377.0 MB 2.8 MB/s eta 0:02:05
#    -- ------------------------------------- 25.4/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 25.6/377.0 MB 2.9 MB/s eta 0:02:00
#    -- ------------------------------------- 25.7/377.0 MB 2.9 MB/s eta 0:02:01
#    -- ------------------------------------- 25.9/377.0 MB 2.9 MB/s eta 0:02:02
#    -- ------------------------------------- 26.0/377.0 MB 2.9 MB/s eta 0:02:02
#    -- ------------------------------------- 26.1/377.0 MB 2.9 MB/s eta 0:02:01
#    -- ------------------------------------- 26.3/377.0 MB 2.9 MB/s eta 0:02:01
#    -- ------------------------------------- 26.4/377.0 MB 2.9 MB/s eta 0:02:02
#    -- ------------------------------------- 26.6/377.0 MB 2.9 MB/s eta 0:01:59
#    -- ------------------------------------- 26.8/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 26.9/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 27.0/377.0 MB 2.9 MB/s eta 0:01:59
#    -- ------------------------------------- 27.1/377.0 MB 2.9 MB/s eta 0:01:59
#    -- ------------------------------------- 27.3/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 27.4/377.0 MB 2.9 MB/s eta 0:02:00
#    -- ------------------------------------- 27.6/377.0 MB 3.0 MB/s eta 0:01:57
#    -- ------------------------------------- 27.7/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 27.9/377.0 MB 3.0 MB/s eta 0:01:58
#    -- ------------------------------------- 28.1/377.0 MB 2.9 MB/s eta 0:01:59
#    -- ------------------------------------- 28.2/377.0 MB 2.9 MB/s eta 0:02:00
#    --- ------------------------------------ 28.3/377.0 MB 2.9 MB/s eta 0:02:00
#    --- ------------------------------------ 28.5/377.0 MB 2.9 MB/s eta 0:02:01
#    --- ------------------------------------ 28.6/377.0 MB 2.9 MB/s eta 0:02:01
#    --- ------------------------------------ 28.8/377.0 MB 2.9 MB/s eta 0:02:00
#    --- ------------------------------------ 28.9/377.0 MB 2.9 MB/s eta 0:02:00
#    --- ------------------------------------ 29.0/377.0 MB 2.9 MB/s eta 0:02:01
#    --- ------------------------------------ 29.2/377.0 MB 2.9 MB/s eta 0:02:00
#    --- ------------------------------------ 29.3/377.0 MB 2.9 MB/s eta 0:01:59
#    --- ------------------------------------ 29.3/377.0 MB 2.9 MB/s eta 0:01:59
#    --- ------------------------------------ 29.3/377.0 MB 2.9 MB/s eta 0:01:59
#    --- ------------------------------------ 29.3/377.0 MB 2.8 MB/s eta 0:02:04
#    --- ------------------------------------ 29.4/377.0 MB 2.8 MB/s eta 0:02:06
#    --- ------------------------------------ 29.4/377.0 MB 2.7 MB/s eta 0:02:07
#    --- ------------------------------------ 29.4/377.0 MB 2.7 MB/s eta 0:02:08
#    --- ------------------------------------ 29.7/377.0 MB 2.7 MB/s eta 0:02:09
#    --- ------------------------------------ 29.8/377.0 MB 2.7 MB/s eta 0:02:09
#    --- ------------------------------------ 29.8/377.0 MB 2.7 MB/s eta 0:02:09
#    --- ------------------------------------ 29.9/377.0 MB 2.7 MB/s eta 0:02:10
#    --- ------------------------------------ 30.1/377.0 MB 2.6 MB/s eta 0:02:12
#    --- ------------------------------------ 30.2/377.0 MB 2.7 MB/s eta 0:02:10
#    --- ------------------------------------ 30.4/377.0 MB 2.7 MB/s eta 0:02:11
#    --- ------------------------------------ 30.4/377.0 MB 2.6 MB/s eta 0:02:12
#    --- ------------------------------------ 30.4/377.0 MB 2.6 MB/s eta 0:02:13
#    --- ------------------------------------ 30.4/377.0 MB 2.6 MB/s eta 0:02:13
#    --- ------------------------------------ 30.4/377.0 MB 2.6 MB/s eta 0:02:13
#    --- ------------------------------------ 30.4/377.0 MB 2.6 MB/s eta 0:02:13
#    --- ------------------------------------ 30.4/377.0 MB 2.6 MB/s eta 0:02:13
#    --- ------------------------------------ 30.8/377.0 MB 2.5 MB/s eta 0:02:19
#    --- ------------------------------------ 30.8/377.0 MB 2.5 MB/s eta 0:02:19
#    --- ------------------------------------ 30.8/377.0 MB 2.5 MB/s eta 0:02:19
#    --- ------------------------------------ 30.8/377.0 MB 2.4 MB/s eta 0:02:23
#    --- ------------------------------------ 30.8/377.0 MB 2.4 MB/s eta 0:02:23
#    --- ------------------------------------ 30.9/377.0 MB 2.4 MB/s eta 0:02:26
#    --- ------------------------------------ 31.0/377.0 MB 2.3 MB/s eta 0:02:28
#    --- ------------------------------------ 31.1/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 31.2/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 31.3/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 31.4/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 31.6/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 31.7/377.0 MB 2.3 MB/s eta 0:02:30
#    --- ------------------------------------ 31.8/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 32.0/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 32.3/377.0 MB 2.3 MB/s eta 0:02:28
#    --- ------------------------------------ 32.4/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 32.6/377.0 MB 2.3 MB/s eta 0:02:30
#    --- ------------------------------------ 32.8/377.0 MB 2.3 MB/s eta 0:02:28
#    --- ------------------------------------ 32.8/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 32.8/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 32.8/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 32.8/377.0 MB 2.3 MB/s eta 0:02:29
#    --- ------------------------------------ 33.0/377.0 MB 2.2 MB/s eta 0:02:34
#    --- ------------------------------------ 33.2/377.0 MB 2.2 MB/s eta 0:02:34
#    --- ------------------------------------ 33.4/377.0 MB 2.3 MB/s eta 0:02:32
#    --- ------------------------------------ 33.5/377.0 MB 2.3 MB/s eta 0:02:33
#    --- ------------------------------------ 33.6/377.0 MB 2.2 MB/s eta 0:02:33
#    --- ------------------------------------ 33.6/377.0 MB 2.2 MB/s eta 0:02:34
#    --- ------------------------------------ 33.8/377.0 MB 2.2 MB/s eta 0:02:35
#    --- ------------------------------------ 33.9/377.0 MB 2.2 MB/s eta 0:02:36
#    --- ------------------------------------ 33.9/377.0 MB 2.2 MB/s eta 0:02:37
#    --- ------------------------------------ 34.0/377.0 MB 2.3 MB/s eta 0:02:32
#    --- ------------------------------------ 34.0/377.0 MB 2.3 MB/s eta 0:02:32
#    --- ------------------------------------ 34.0/377.0 MB 2.3 MB/s eta 0:02:32
#    --- ------------------------------------ 34.0/377.0 MB 2.3 MB/s eta 0:02:32
#    --- ------------------------------------ 34.0/377.0 MB 2.2 MB/s eta 0:02:39
#    --- ------------------------------------ 34.3/377.0 MB 2.2 MB/s eta 0:02:39
#    --- ------------------------------------ 34.4/377.0 MB 2.1 MB/s eta 0:02:41
#    --- ------------------------------------ 34.4/377.0 MB 2.1 MB/s eta 0:02:41
#    --- ------------------------------------ 35.0/377.0 MB 2.2 MB/s eta 0:02:35
#    --- ------------------------------------ 35.1/377.0 MB 2.3 MB/s eta 0:02:28
#    --- ------------------------------------ 35.2/377.0 MB 2.4 MB/s eta 0:02:25
#    --- ------------------------------------ 35.5/377.0 MB 2.3 MB/s eta 0:02:27
#    --- ------------------------------------ 35.6/377.0 MB 2.3 MB/s eta 0:02:27
#    --- ------------------------------------ 35.7/377.0 MB 2.3 MB/s eta 0:02:27
#    --- ------------------------------------ 35.8/377.0 MB 2.3 MB/s eta 0:02:28
#    --- ------------------------------------ 36.0/377.0 MB 2.3 MB/s eta 0:02:28
#    --- ------------------------------------ 36.2/377.0 MB 2.3 MB/s eta 0:02:27
#    --- ------------------------------------ 36.3/377.0 MB 2.3 MB/s eta 0:02:27
#    --- ------------------------------------ 36.4/377.0 MB 2.3 MB/s eta 0:02:27
#    --- ------------------------------------ 36.7/377.0 MB 2.3 MB/s eta 0:02:26
#    --- ------------------------------------ 36.7/377.0 MB 2.3 MB/s eta 0:02:27
#    --- ------------------------------------ 37.0/377.0 MB 2.3 MB/s eta 0:02:26
#    --- ------------------------------------ 37.1/377.0 MB 2.3 MB/s eta 0:02:26
#    --- ------------------------------------ 37.2/377.0 MB 2.3 MB/s eta 0:02:25
#    --- ------------------------------------ 37.4/377.0 MB 2.3 MB/s eta 0:02:26
#    --- ------------------------------------ 37.6/377.0 MB 2.4 MB/s eta 0:02:25
#    ---- ----------------------------------- 37.8/377.0 MB 2.4 MB/s eta 0:02:25
#    ---- ----------------------------------- 37.9/377.0 MB 2.4 MB/s eta 0:02:23
#    ---- ----------------------------------- 38.1/377.0 MB 2.3 MB/s eta 0:02:25
#    ---- ----------------------------------- 38.2/377.0 MB 2.4 MB/s eta 0:02:24
#    ---- ----------------------------------- 38.2/377.0 MB 2.4 MB/s eta 0:02:24
#    ---- ----------------------------------- 38.3/377.0 MB 2.3 MB/s eta 0:02:26
#    ---- ----------------------------------- 38.5/377.0 MB 2.3 MB/s eta 0:02:26
#    ---- ----------------------------------- 38.6/377.0 MB 2.3 MB/s eta 0:02:25
#    ---- ----------------------------------- 38.6/377.0 MB 2.3 MB/s eta 0:02:25
#    ---- ----------------------------------- 38.6/377.0 MB 2.3 MB/s eta 0:02:25
#    ---- ----------------------------------- 38.6/377.0 MB 2.3 MB/s eta 0:02:25
#    ---- ----------------------------------- 39.0/377.0 MB 2.3 MB/s eta 0:02:29
#    ---- ----------------------------------- 39.6/377.0 MB 2.5 MB/s eta 0:02:18
#    ---- ----------------------------------- 39.8/377.0 MB 2.5 MB/s eta 0:02:16
#    ---- ----------------------------------- 40.0/377.0 MB 2.5 MB/s eta 0:02:16
#    ---- ----------------------------------- 40.1/377.0 MB 2.5 MB/s eta 0:02:15
#    ---- ----------------------------------- 40.3/377.0 MB 2.5 MB/s eta 0:02:14
#    ---- ----------------------------------- 40.6/377.0 MB 2.5 MB/s eta 0:02:13
#    ---- ----------------------------------- 40.8/377.0 MB 2.7 MB/s eta 0:02:05
#    ---- ----------------------------------- 40.9/377.0 MB 2.7 MB/s eta 0:02:06
#    ---- ----------------------------------- 41.1/377.0 MB 2.9 MB/s eta 0:01:57
#    ---- ----------------------------------- 41.3/377.0 MB 2.9 MB/s eta 0:01:57
#    ---- ----------------------------------- 41.5/377.0 MB 2.9 MB/s eta 0:01:56
#    ---- ----------------------------------- 41.6/377.0 MB 2.9 MB/s eta 0:01:55
#    ---- ----------------------------------- 41.6/377.0 MB 2.9 MB/s eta 0:01:55
#    ---- ----------------------------------- 41.6/377.0 MB 2.9 MB/s eta 0:01:55
#    ---- ----------------------------------- 42.1/377.0 MB 3.0 MB/s eta 0:01:54
#    ---- ----------------------------------- 42.4/377.0 MB 2.9 MB/s eta 0:01:54
#    ---- ----------------------------------- 42.6/377.0 MB 2.9 MB/s eta 0:01:54
#    ---- ----------------------------------- 42.8/377.0 MB 3.0 MB/s eta 0:01:53
#    ---- ----------------------------------- 42.9/377.0 MB 3.0 MB/s eta 0:01:53
#    ---- ----------------------------------- 43.1/377.0 MB 3.1 MB/s eta 0:01:48
#    ---- ----------------------------------- 43.3/377.0 MB 3.1 MB/s eta 0:01:47
#    ---- ----------------------------------- 43.7/377.0 MB 3.2 MB/s eta 0:01:45
#    ---- ----------------------------------- 43.9/377.0 MB 3.2 MB/s eta 0:01:45
#    ---- ----------------------------------- 44.2/377.0 MB 3.3 MB/s eta 0:01:40
#    ---- ----------------------------------- 44.4/377.0 MB 3.6 MB/s eta 0:01:33
#    ---- ----------------------------------- 44.7/377.0 MB 3.7 MB/s eta 0:01:30
#    ---- ----------------------------------- 44.9/377.0 MB 3.7 MB/s eta 0:01:31
#    ---- ----------------------------------- 45.0/377.0 MB 3.6 MB/s eta 0:01:32
#    ---- ----------------------------------- 45.3/377.0 MB 3.6 MB/s eta 0:01:32
#    ---- ----------------------------------- 45.4/377.0 MB 3.6 MB/s eta 0:01:32
#    ---- ----------------------------------- 45.6/377.0 MB 3.6 MB/s eta 0:01:33
#    ---- ----------------------------------- 45.9/377.0 MB 3.7 MB/s eta 0:01:31
#    ---- ----------------------------------- 46.1/377.0 MB 3.7 MB/s eta 0:01:30
#    ---- ----------------------------------- 46.3/377.0 MB 3.8 MB/s eta 0:01:28
#    ---- ----------------------------------- 46.6/377.0 MB 3.8 MB/s eta 0:01:27
#    ---- ----------------------------------- 46.8/377.0 MB 3.8 MB/s eta 0:01:27
#    ----- ---------------------------------- 47.2/377.0 MB 3.9 MB/s eta 0:01:25
#    ----- ---------------------------------- 47.5/377.0 MB 4.0 MB/s eta 0:01:24
#    ----- ---------------------------------- 47.8/377.0 MB 4.0 MB/s eta 0:01:22
#    ----- ---------------------------------- 48.0/377.0 MB 4.0 MB/s eta 0:01:22
#    ----- ---------------------------------- 48.3/377.0 MB 4.1 MB/s eta 0:01:20
#    ----- ---------------------------------- 48.6/377.0 MB 4.3 MB/s eta 0:01:17
#    ----- ---------------------------------- 48.8/377.0 MB 4.3 MB/s eta 0:01:16
#    ----- ---------------------------------- 48.9/377.0 MB 4.7 MB/s eta 0:01:11
#    ----- ---------------------------------- 49.1/377.0 MB 4.6 MB/s eta 0:01:12
#    ----- ---------------------------------- 49.5/377.0 MB 4.6 MB/s eta 0:01:11
#    ----- ---------------------------------- 49.7/377.0 MB 4.6 MB/s eta 0:01:12
#    ----- ---------------------------------- 50.1/377.0 MB 4.6 MB/s eta 0:01:11
#    ----- ---------------------------------- 50.5/377.0 MB 4.8 MB/s eta 0:01:09
#    ----- ---------------------------------- 50.8/377.0 MB 4.8 MB/s eta 0:01:08
#    ----- ---------------------------------- 51.1/377.0 MB 4.9 MB/s eta 0:01:07
#    ----- ---------------------------------- 51.2/377.0 MB 4.9 MB/s eta 0:01:07
#    ----- ---------------------------------- 51.3/377.0 MB 4.8 MB/s eta 0:01:09
#    ----- ---------------------------------- 51.6/377.0 MB 4.9 MB/s eta 0:01:07
#    ----- ---------------------------------- 51.8/377.0 MB 4.9 MB/s eta 0:01:07
#    ----- ---------------------------------- 51.8/377.0 MB 4.9 MB/s eta 0:01:07
#    ----- ---------------------------------- 51.8/377.0 MB 4.9 MB/s eta 0:01:07
#    ----- ---------------------------------- 52.3/377.0 MB 4.9 MB/s eta 0:01:06
#    ----- ---------------------------------- 52.7/377.0 MB 5.0 MB/s eta 0:01:05
#    ----- ---------------------------------- 52.7/377.0 MB 4.9 MB/s eta 0:01:07
#    ----- ---------------------------------- 52.7/377.0 MB 4.9 MB/s eta 0:01:07
#    ----- ---------------------------------- 52.7/377.0 MB 4.9 MB/s eta 0:01:07
#    ----- ---------------------------------- 53.2/377.0 MB 4.9 MB/s eta 0:01:07
#    ----- ---------------------------------- 53.2/377.0 MB 4.7 MB/s eta 0:01:09
#    ----- ---------------------------------- 53.5/377.0 MB 4.9 MB/s eta 0:01:07
#    ----- ---------------------------------- 53.9/377.0 MB 4.9 MB/s eta 0:01:06
#    ----- ---------------------------------- 53.9/377.0 MB 4.9 MB/s eta 0:01:06
#    ----- ---------------------------------- 54.3/377.0 MB 4.8 MB/s eta 0:01:08
#    ----- ---------------------------------- 54.3/377.0 MB 4.7 MB/s eta 0:01:08
#    ----- ---------------------------------- 54.3/377.0 MB 4.7 MB/s eta 0:01:08
#    ----- ---------------------------------- 54.3/377.0 MB 4.7 MB/s eta 0:01:08
#    ----- ---------------------------------- 55.4/377.0 MB 5.0 MB/s eta 0:01:05
#    ----- ---------------------------------- 55.4/377.0 MB 4.8 MB/s eta 0:01:07
#    ----- ---------------------------------- 55.8/377.0 MB 5.0 MB/s eta 0:01:05
#    ----- ---------------------------------- 56.0/377.0 MB 4.8 MB/s eta 0:01:07
#    ----- ---------------------------------- 56.1/377.0 MB 4.8 MB/s eta 0:01:07
#    ----- ---------------------------------- 56.5/377.0 MB 4.9 MB/s eta 0:01:06
#    ------ --------------------------------- 56.7/377.0 MB 4.9 MB/s eta 0:01:06
#    ------ --------------------------------- 56.9/377.0 MB 4.9 MB/s eta 0:01:06
#    ------ --------------------------------- 57.3/377.0 MB 4.9 MB/s eta 0:01:05
#    ------ --------------------------------- 57.6/377.0 MB 4.9 MB/s eta 0:01:06
#    ------ --------------------------------- 58.0/377.0 MB 4.9 MB/s eta 0:01:06
#    ------ --------------------------------- 58.2/377.0 MB 4.9 MB/s eta 0:01:06
#    ------ --------------------------------- 58.5/377.0 MB 4.8 MB/s eta 0:01:06
#    ------ --------------------------------- 58.7/377.0 MB 4.9 MB/s eta 0:01:06
#    ------ --------------------------------- 59.0/377.0 MB 4.9 MB/s eta 0:01:05
#    ------ --------------------------------- 59.2/377.0 MB 5.0 MB/s eta 0:01:04
#    ------ --------------------------------- 59.4/377.0 MB 5.0 MB/s eta 0:01:04
#    ------ --------------------------------- 59.7/377.0 MB 4.9 MB/s eta 0:01:05
#    ------ --------------------------------- 59.8/377.0 MB 4.8 MB/s eta 0:01:06
#    ------ --------------------------------- 59.9/377.0 MB 4.7 MB/s eta 0:01:07
#    ------ --------------------------------- 60.2/377.0 MB 4.8 MB/s eta 0:01:07
#    ------ --------------------------------- 60.3/377.0 MB 4.8 MB/s eta 0:01:07
#    ------ --------------------------------- 60.3/377.0 MB 4.8 MB/s eta 0:01:07
#    ------ --------------------------------- 60.8/377.0 MB 4.6 MB/s eta 0:01:09
#    ------ --------------------------------- 61.1/377.0 MB 4.6 MB/s eta 0:01:09
#    ------ --------------------------------- 61.2/377.0 MB 4.6 MB/s eta 0:01:09
#    ------ --------------------------------- 61.4/377.0 MB 4.6 MB/s eta 0:01:09
#    ------ --------------------------------- 61.5/377.0 MB 4.5 MB/s eta 0:01:10
#    ------ --------------------------------- 61.8/377.0 MB 4.6 MB/s eta 0:01:09
#    ------ --------------------------------- 62.0/377.0 MB 4.5 MB/s eta 0:01:10
#    ------ --------------------------------- 62.3/377.0 MB 4.8 MB/s eta 0:01:06
#    ------ --------------------------------- 62.5/377.0 MB 4.7 MB/s eta 0:01:07
#    ------ --------------------------------- 62.8/377.0 MB 4.6 MB/s eta 0:01:09
#    ------ --------------------------------- 62.9/377.0 MB 4.9 MB/s eta 0:01:04
#    ------ --------------------------------- 63.1/377.0 MB 4.8 MB/s eta 0:01:06
#    ------ --------------------------------- 63.8/377.0 MB 5.0 MB/s eta 0:01:03
#    ------ --------------------------------- 63.9/377.0 MB 4.9 MB/s eta 0:01:05
#    ------ --------------------------------- 64.2/377.0 MB 4.8 MB/s eta 0:01:05
#    ------ --------------------------------- 64.5/377.0 MB 5.0 MB/s eta 0:01:03
#    ------ --------------------------------- 64.8/377.0 MB 5.2 MB/s eta 0:01:00
#    ------ --------------------------------- 65.2/377.0 MB 5.2 MB/s eta 0:01:01
#    ------ --------------------------------- 65.5/377.0 MB 5.0 MB/s eta 0:01:02
#    ------ --------------------------------- 65.5/377.0 MB 5.0 MB/s eta 0:01:02
#    ------ --------------------------------- 65.7/377.0 MB 5.0 MB/s eta 0:01:03
#    ------ --------------------------------- 65.8/377.0 MB 4.9 MB/s eta 0:01:04
#    ------ --------------------------------- 65.9/377.0 MB 4.8 MB/s eta 0:01:05
#    ------- -------------------------------- 66.1/377.0 MB 4.8 MB/s eta 0:01:05
#    ------- -------------------------------- 66.2/377.0 MB 4.7 MB/s eta 0:01:06
#    ------- -------------------------------- 66.2/377.0 MB 4.7 MB/s eta 0:01:06
#    ------- -------------------------------- 66.3/377.0 MB 4.7 MB/s eta 0:01:07
#    ------- -------------------------------- 66.8/377.0 MB 4.7 MB/s eta 0:01:07
#    ------- -------------------------------- 67.2/377.0 MB 4.8 MB/s eta 0:01:05
#    ------- -------------------------------- 67.4/377.0 MB 4.7 MB/s eta 0:01:06
#    ------- -------------------------------- 67.4/377.0 MB 4.7 MB/s eta 0:01:06
#    ------- -------------------------------- 67.9/377.0 MB 4.7 MB/s eta 0:01:06
#    ------- -------------------------------- 68.1/377.0 MB 4.7 MB/s eta 0:01:07
#    ------- -------------------------------- 68.3/377.0 MB 4.7 MB/s eta 0:01:06
#    ------- -------------------------------- 68.4/377.0 MB 4.7 MB/s eta 0:01:06
#    ------- -------------------------------- 68.4/377.0 MB 4.7 MB/s eta 0:01:06
#    ------- -------------------------------- 68.5/377.0 MB 4.5 MB/s eta 0:01:09
#    ------- -------------------------------- 69.3/377.0 MB 4.6 MB/s eta 0:01:07
#    ------- -------------------------------- 69.5/377.0 MB 4.6 MB/s eta 0:01:08
#    ------- -------------------------------- 69.5/377.0 MB 4.6 MB/s eta 0:01:08
#    ------- -------------------------------- 69.9/377.0 MB 4.6 MB/s eta 0:01:07
#    ------- -------------------------------- 70.2/377.0 MB 4.7 MB/s eta 0:01:06
#    ------- -------------------------------- 70.9/377.0 MB 5.0 MB/s eta 0:01:02
#    ------- -------------------------------- 71.3/377.0 MB 5.0 MB/s eta 0:01:02
#    ------- -------------------------------- 71.6/377.0 MB 5.2 MB/s eta 0:00:59
#    ------- -------------------------------- 71.8/377.0 MB 5.2 MB/s eta 0:01:00
#    ------- -------------------------------- 72.3/377.0 MB 5.3 MB/s eta 0:00:58
#    ------- -------------------------------- 72.6/377.0 MB 5.3 MB/s eta 0:00:58
#    ------- -------------------------------- 72.8/377.0 MB 5.5 MB/s eta 0:00:56
#    ------- -------------------------------- 73.3/377.0 MB 5.5 MB/s eta 0:00:55
#    ------- -------------------------------- 73.7/377.0 MB 5.4 MB/s eta 0:00:57
#    ------- -------------------------------- 74.2/377.0 MB 5.6 MB/s eta 0:00:55
#    ------- -------------------------------- 74.5/377.0 MB 5.5 MB/s eta 0:00:55
#    ------- -------------------------------- 74.6/377.0 MB 5.5 MB/s eta 0:00:55
#    ------- -------------------------------- 74.8/377.0 MB 5.6 MB/s eta 0:00:55
#    ------- -------------------------------- 75.1/377.0 MB 5.5 MB/s eta 0:00:55
#    ------- -------------------------------- 75.3/377.0 MB 5.4 MB/s eta 0:00:57
#    ------- -------------------------------- 75.3/377.0 MB 5.4 MB/s eta 0:00:57
#    ------- -------------------------------- 75.3/377.0 MB 5.4 MB/s eta 0:00:57
#    -------- ------------------------------- 76.3/377.0 MB 5.8 MB/s eta 0:00:52
#    -------- ------------------------------- 76.7/377.0 MB 6.4 MB/s eta 0:00:48
#    -------- ------------------------------- 76.8/377.0 MB 6.2 MB/s eta 0:00:49
#    -------- ------------------------------- 77.1/377.0 MB 6.1 MB/s eta 0:00:50
#    -------- ------------------------------- 77.3/377.0 MB 5.9 MB/s eta 0:00:51
#    -------- ------------------------------- 77.5/377.0 MB 6.0 MB/s eta 0:00:51
#    -------- ------------------------------- 77.7/377.0 MB 6.3 MB/s eta 0:00:48
#    -------- ------------------------------- 78.0/377.0 MB 6.0 MB/s eta 0:00:51
#    -------- ------------------------------- 78.7/377.0 MB 6.8 MB/s eta 0:00:44
#    -------- ------------------------------- 78.8/377.0 MB 6.7 MB/s eta 0:00:45
#    -------- ------------------------------- 78.9/377.0 MB 6.5 MB/s eta 0:00:46
#    -------- ------------------------------- 78.9/377.0 MB 6.4 MB/s eta 0:00:47
#    -------- ------------------------------- 79.2/377.0 MB 6.2 MB/s eta 0:00:49
#    -------- ------------------------------- 79.2/377.0 MB 6.2 MB/s eta 0:00:49
#    -------- ------------------------------- 79.2/377.0 MB 6.2 MB/s eta 0:00:49
#    -------- ------------------------------- 79.2/377.0 MB 6.2 MB/s eta 0:00:49
#    -------- ------------------------------- 79.2/377.0 MB 6.2 MB/s eta 0:00:49
#    -------- ------------------------------- 79.2/377.0 MB 6.2 MB/s eta 0:00:49
#    -------- ------------------------------- 79.2/377.0 MB 6.2 MB/s eta 0:00:49
#    -------- ------------------------------- 79.2/377.0 MB 5.1 MB/s eta 0:00:59
#    -------- ------------------------------- 79.2/377.0 MB 5.1 MB/s eta 0:00:59
#    -------- ------------------------------- 80.3/377.0 MB 5.4 MB/s eta 0:00:55
#    -------- ------------------------------- 80.6/377.0 MB 5.3 MB/s eta 0:00:56
#    -------- ------------------------------- 80.7/377.0 MB 5.3 MB/s eta 0:00:57
#    -------- ------------------------------- 80.7/377.0 MB 5.3 MB/s eta 0:00:57
#    -------- ------------------------------- 80.7/377.0 MB 5.3 MB/s eta 0:00:57
#    -------- ------------------------------- 81.4/377.0 MB 5.0 MB/s eta 0:00:59
#    -------- ------------------------------- 81.4/377.0 MB 5.0 MB/s eta 0:01:00
#    -------- ------------------------------- 81.4/377.0 MB 5.0 MB/s eta 0:01:00
#    -------- ------------------------------- 81.4/377.0 MB 5.0 MB/s eta 0:01:00
#    -------- ------------------------------- 81.4/377.0 MB 5.0 MB/s eta 0:01:00
#    -------- ------------------------------- 81.5/377.0 MB 4.5 MB/s eta 0:01:05
#    -------- ------------------------------- 81.7/377.0 MB 4.4 MB/s eta 0:01:07
#    -------- ------------------------------- 81.8/377.0 MB 4.4 MB/s eta 0:01:08
#    -------- ------------------------------- 81.9/377.0 MB 4.4 MB/s eta 0:01:07
#    -------- ------------------------------- 81.9/377.0 MB 4.4 MB/s eta 0:01:07
#    -------- ------------------------------- 81.9/377.0 MB 4.4 MB/s eta 0:01:07
#    -------- ------------------------------- 81.9/377.0 MB 4.1 MB/s eta 0:01:12
#    -------- ------------------------------- 82.6/377.0 MB 4.2 MB/s eta 0:01:11
#    -------- ------------------------------- 82.7/377.0 MB 4.2 MB/s eta 0:01:11
#    -------- ------------------------------- 82.9/377.0 MB 4.1 MB/s eta 0:01:12
#    -------- ------------------------------- 83.0/377.0 MB 4.0 MB/s eta 0:01:13
#    -------- ------------------------------- 83.0/377.0 MB 4.0 MB/s eta 0:01:14
#    -------- ------------------------------- 83.3/377.0 MB 4.0 MB/s eta 0:01:14
#    -------- ------------------------------- 83.8/377.0 MB 4.0 MB/s eta 0:01:14
#    -------- ------------------------------- 83.9/377.0 MB 4.0 MB/s eta 0:01:14
#    -------- ------------------------------- 84.1/377.0 MB 3.9 MB/s eta 0:01:15
#    -------- ------------------------------- 84.3/377.0 MB 3.9 MB/s eta 0:01:16
#    -------- ------------------------------- 84.3/377.0 MB 3.9 MB/s eta 0:01:16
#    -------- ------------------------------- 84.5/377.0 MB 3.8 MB/s eta 0:01:18
#    --------- ------------------------------ 84.9/377.0 MB 3.8 MB/s eta 0:01:17
#    --------- ------------------------------ 85.2/377.0 MB 3.9 MB/s eta 0:01:16
#    --------- ------------------------------ 85.4/377.0 MB 3.9 MB/s eta 0:01:16
#    --------- ------------------------------ 85.7/377.0 MB 4.0 MB/s eta 0:01:13
#    --------- ------------------------------ 85.7/377.0 MB 3.9 MB/s eta 0:01:15
#    --------- ------------------------------ 86.0/377.0 MB 3.9 MB/s eta 0:01:16
#    --------- ------------------------------ 86.1/377.0 MB 3.8 MB/s eta 0:01:17
#    --------- ------------------------------ 86.1/377.0 MB 3.8 MB/s eta 0:01:17
#    --------- ------------------------------ 86.1/377.0 MB 3.8 MB/s eta 0:01:17
#    --------- ------------------------------ 86.5/377.0 MB 3.7 MB/s eta 0:01:20
#    --------- ------------------------------ 86.5/377.0 MB 3.7 MB/s eta 0:01:20
#    --------- ------------------------------ 87.2/377.0 MB 3.7 MB/s eta 0:01:20
#    --------- ------------------------------ 87.3/377.0 MB 3.7 MB/s eta 0:01:20
#    --------- ------------------------------ 87.3/377.0 MB 3.7 MB/s eta 0:01:20
#    --------- ------------------------------ 87.9/377.0 MB 3.6 MB/s eta 0:01:20
#    --------- ------------------------------ 88.1/377.0 MB 3.7 MB/s eta 0:01:19
#    --------- ------------------------------ 88.4/377.0 MB 3.6 MB/s eta 0:01:20
#    --------- ------------------------------ 88.6/377.0 MB 3.6 MB/s eta 0:01:21
#    --------- ------------------------------ 88.7/377.0 MB 3.6 MB/s eta 0:01:22
#    --------- ------------------------------ 89.0/377.0 MB 3.6 MB/s eta 0:01:21
#    --------- ------------------------------ 89.3/377.0 MB 3.7 MB/s eta 0:01:19
#    --------- ------------------------------ 89.6/377.0 MB 4.3 MB/s eta 0:01:08
# ...
#    ---------------------------------------  377.0/377.0 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------  377.0/377.0 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 377.0/377.0 MB 3.3 MB/s eta 0:00:00
# Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Downloading gast-0.5.4-py3-none-any.whl (19 kB)
# Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#    ---------------------------------------- 0.0/57.5 kB ? eta -:--:--
#    ---------------------------------------- 57.5/57.5 kB 3.1 MB/s eta 0:00:00
# Downloading grpcio-1.64.1-cp311-cp311-win_amd64.whl (4.1 MB)
#    ---------------------------------------- 0.0/4.1 MB ? eta -:--:--
#    ---- ----------------------------------- 0.4/4.1 MB 8.5 MB/s eta 0:00:01
#    ------- -------------------------------- 0.8/4.1 MB 8.0 MB/s eta 0:00:01
#    --------- ------------------------------ 1.0/4.1 MB 6.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.1/4.1 MB 5.9 MB/s eta 0:00:01
#    ------------ --------------------------- 1.2/4.1 MB 6.0 MB/s eta 0:00:01
#    ------------ --------------------------- 1.2/4.1 MB 6.0 MB/s eta 0:00:01
#    ------------ --------------------------- 1.2/4.1 MB 6.0 MB/s eta 0:00:01
#    ------------ --------------------------- 1.2/4.1 MB 6.0 MB/s eta 0:00:01
#    -------------- ------------------------- 1.5/4.1 MB 3.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.4/4.1 MB 5.3 MB/s eta 0:00:01
#    --------------------------- ------------ 2.8/4.1 MB 5.4 MB/s eta 0:00:01
#    ------------------------------ --------- 3.1/4.1 MB 5.6 MB/s eta 0:00:01
#    -------------------------------- ------- 3.3/4.1 MB 5.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.6/4.1 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.6/4.1 MB 5.7 MB/s eta 0:00:01
#    ---------------------------------------- 4.1/4.1 MB 5.4 MB/s eta 0:00:00
# Downloading h5py-3.11.0-cp311-cp311-win_amd64.whl (3.0 MB)
#    ---------------------------------------- 0.0/3.0 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/3.0 MB 6.3 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.4/3.0 MB 4.6 MB/s eta 0:00:01
#    --------- ------------------------------ 0.7/3.0 MB 4.8 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.8/3.0 MB 4.9 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.8/3.0 MB 3.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.8/3.0 MB 6.7 MB/s eta 0:00:01
#    --------------------------- ------------ 2.1/3.0 MB 7.0 MB/s eta 0:00:01
#    ------------------------------- -------- 2.4/3.0 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.6/3.0 MB 6.4 MB/s eta 0:00:01
#    ------------------------------------- -- 2.8/3.0 MB 6.2 MB/s eta 0:00:01
#    -------------------------------------- - 2.9/3.0 MB 6.2 MB/s eta 0:00:01
#    -------------------------------------- - 2.9/3.0 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  3.0/3.0 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 3.0/3.0 MB 4.9 MB/s eta 0:00:00
# Downloading keras-3.3.3-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------- ----------------------------- 0.3/1.1 MB 8.6 MB/s eta 0:00:01
#    -------------------- ------------------- 0.6/1.1 MB 8.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.7/1.1 MB 7.0 MB/s eta 0:00:01
#    -------------------------------- ------- 0.9/1.1 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  1.1/1.1 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 4.7 MB/s eta 0:00:00
# Downloading libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/26.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/26.4 MB 3.9 MB/s eta 0:00:07
#    - -------------------------------------- 0.8/26.4 MB 5.4 MB/s eta 0:00:05
#    - -------------------------------------- 1.1/26.4 MB 5.8 MB/s eta 0:00:05
#    -- ------------------------------------- 1.9/26.4 MB 7.3 MB/s eta 0:00:04
#    --- ------------------------------------ 2.1/26.4 MB 7.0 MB/s eta 0:00:04
#    --- ------------------------------------ 2.1/26.4 MB 6.7 MB/s eta 0:00:04
#    --- ------------------------------------ 2.1/26.4 MB 5.2 MB/s eta 0:00:05
#    --- ------------------------------------ 2.1/26.4 MB 5.2 MB/s eta 0:00:05
#    --- ------------------------------------ 2.1/26.4 MB 4.3 MB/s eta 0:00:06
#    --- ------------------------------------ 2.3/26.4 MB 4.2 MB/s eta 0:00:06
#    --- ------------------------------------ 2.5/26.4 MB 4.4 MB/s eta 0:00:06
#    ---- ----------------------------------- 2.8/26.4 MB 4.5 MB/s eta 0:00:06
#    ---- ----------------------------------- 3.2/26.4 MB 4.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.4/26.4 MB 4.8 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.5/26.4 MB 4.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.8/26.4 MB 4.7 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.9/26.4 MB 4.7 MB/s eta 0:00:05
#    ------ --------------------------------- 4.0/26.4 MB 4.7 MB/s eta 0:00:05
#    ------ --------------------------------- 4.0/26.4 MB 4.7 MB/s eta 0:00:05
#    ------ --------------------------------- 4.0/26.4 MB 4.7 MB/s eta 0:00:05
#    ------ --------------------------------- 4.5/26.4 MB 4.5 MB/s eta 0:00:05
#    ------ --------------------------------- 4.5/26.4 MB 4.2 MB/s eta 0:00:06
#    -------- ------------------------------- 5.5/26.4 MB 4.9 MB/s eta 0:00:05
#    -------- ------------------------------- 5.7/26.4 MB 5.0 MB/s eta 0:00:05
#    -------- ------------------------------- 5.9/26.4 MB 4.9 MB/s eta 0:00:05
#    --------- ------------------------------ 6.1/26.4 MB 4.9 MB/s eta 0:00:05
#    --------- ------------------------------ 6.3/26.4 MB 5.0 MB/s eta 0:00:05
#    --------- ------------------------------ 6.3/26.4 MB 5.0 MB/s eta 0:00:05
#    --------- ------------------------------ 6.3/26.4 MB 4.5 MB/s eta 0:00:05
#    ----------- ---------------------------- 7.4/26.4 MB 5.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.7/26.4 MB 5.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.7/26.4 MB 5.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.7/26.4 MB 5.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.7/26.4 MB 5.2 MB/s eta 0:00:04
#    ------------- -------------------------- 8.7/26.4 MB 5.2 MB/s eta 0:00:04
#    ------------- -------------------------- 8.7/26.4 MB 5.2 MB/s eta 0:00:04
#    ------------- -------------------------- 8.7/26.4 MB 5.2 MB/s eta 0:00:04
#    ------------- -------------------------- 8.7/26.4 MB 5.2 MB/s eta 0:00:04
#    -------------- ------------------------- 9.8/26.4 MB 5.3 MB/s eta 0:00:04
#    --------------- ------------------------ 10.0/26.4 MB 5.3 MB/s eta 0:00:04
#    --------------- ------------------------ 10.0/26.4 MB 5.3 MB/s eta 0:00:04
#    --------------- ------------------------ 10.0/26.4 MB 5.3 MB/s eta 0:00:04
#    ---------------- ----------------------- 11.1/26.4 MB 5.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 11.3/26.4 MB 5.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 11.3/26.4 MB 5.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 11.3/26.4 MB 5.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 11.3/26.4 MB 5.4 MB/s eta 0:00:03
#    ------------------ --------------------- 12.4/26.4 MB 5.7 MB/s eta 0:00:03
#    ------------------ --------------------- 12.4/26.4 MB 5.7 MB/s eta 0:00:03
#    ------------------- -------------------- 13.2/26.4 MB 5.8 MB/s eta 0:00:03
#    -------------------- ------------------- 13.4/26.4 MB 5.7 MB/s eta 0:00:03
#    -------------------- ------------------- 13.7/26.4 MB 5.8 MB/s eta 0:00:03
#    --------------------- ------------------ 14.0/26.4 MB 5.9 MB/s eta 0:00:03
#    --------------------- ------------------ 14.4/26.4 MB 6.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 14.7/26.4 MB 6.3 MB/s eta 0:00:02
#    ---------------------- ----------------- 15.0/26.4 MB 6.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 15.1/26.4 MB 6.2 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.4/26.4 MB 6.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.5/26.4 MB 6.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.5/26.4 MB 6.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.5/26.4 MB 6.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.5/26.4 MB 6.0 MB/s eta 0:00:02
#    ----------------------- ---------------- 15.7/26.4 MB 5.4 MB/s eta 0:00:02
#    ------------------------- -------------- 16.7/26.4 MB 6.2 MB/s eta 0:00:02
#    ------------------------- -------------- 16.8/26.4 MB 6.1 MB/s eta 0:00:02
#    ------------------------- -------------- 17.2/26.4 MB 5.9 MB/s eta 0:00:02
#    -------------------------- ------------- 17.2/26.4 MB 5.8 MB/s eta 0:00:02
#    -------------------------- ------------- 17.8/26.4 MB 5.8 MB/s eta 0:00:02
#    --------------------------- ------------ 18.2/26.4 MB 6.3 MB/s eta 0:00:02
#    --------------------------- ------------ 18.5/26.4 MB 6.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 18.8/26.4 MB 6.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 19.1/26.4 MB 6.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 19.3/26.4 MB 6.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 19.6/26.4 MB 6.1 MB/s eta 0:00:02
#    ------------------------------ --------- 20.0/26.4 MB 6.0 MB/s eta 0:00:02
#    ------------------------------ --------- 20.3/26.4 MB 6.6 MB/s eta 0:00:01
#    ------------------------------- -------- 20.7/26.4 MB 6.5 MB/s eta 0:00:01
#    -------------------------------- ------- 21.2/26.4 MB 6.2 MB/s eta 0:00:01
#    -------------------------------- ------- 21.6/26.4 MB 6.2 MB/s eta 0:00:01
#    --------------------------------- ------ 21.9/26.4 MB 6.8 MB/s eta 0:00:01
#    --------------------------------- ------ 22.0/26.4 MB 6.6 MB/s eta 0:00:01
#    --------------------------------- ------ 22.2/26.4 MB 6.5 MB/s eta 0:00:01
#    --------------------------------- ------ 22.3/26.4 MB 6.4 MB/s eta 0:00:01
#    --------------------------------- ------ 22.3/26.4 MB 6.4 MB/s eta 0:00:01
#    --------------------------------- ------ 22.3/26.4 MB 6.4 MB/s eta 0:00:01
#    --------------------------------- ------ 22.3/26.4 MB 6.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.5/26.4 MB 6.1 MB/s eta 0:00:01
#    ------------------------------------ --- 23.8/26.4 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 24.0/26.4 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 24.0/26.4 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 24.1/26.4 MB 5.7 MB/s eta 0:00:01
#    ------------------------------------- -- 25.0/26.4 MB 6.1 MB/s eta 0:00:01
#    -------------------------------------- - 25.4/26.4 MB 6.2 MB/s eta 0:00:01
#    -------------------------------------- - 25.6/26.4 MB 6.2 MB/s eta 0:00:01
#    -------------------------------------- - 25.8/26.4 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  25.9/26.4 MB 6.7 MB/s eta 0:00:01
#    ---------------------------------------  26.1/26.4 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------  26.3/26.4 MB 6.4 MB/s eta 0:00:01
#    ---------------------------------------  26.4/26.4 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------- 26.4/26.4 MB 5.7 MB/s eta 0:00:00
# Downloading ml_dtypes-0.3.2-cp311-cp311-win_amd64.whl (127 kB)
#    ---------------------------------------- 0.0/127.7 kB ? eta -:--:--
#    ---------------------------------------- 127.7/127.7 kB 2.5 MB/s eta 0:00:00
# Downloading tensorboard-2.16.2-py3-none-any.whl (5.5 MB)
#    ---------------------------------------- 0.0/5.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/5.5 MB 8.9 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.6/5.5 MB 7.7 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.6/5.5 MB 7.7 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.6/5.5 MB 7.7 MB/s eta 0:00:01
#    ------ --------------------------------- 0.8/5.5 MB 4.0 MB/s eta 0:00:02
#    ------ --------------------------------- 0.8/5.5 MB 4.0 MB/s eta 0:00:02
#    ------ --------------------------------- 0.9/5.5 MB 3.2 MB/s eta 0:00:02
#    -------- ------------------------------- 1.1/5.5 MB 3.2 MB/s eta 0:00:02
#    --------- ------------------------------ 1.3/5.5 MB 3.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.4/5.5 MB 3.3 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.4/5.5 MB 3.3 MB/s eta 0:00:02
#    -------------------- ------------------- 2.8/5.5 MB 5.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.2/5.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------ --------------- 3.3/5.5 MB 5.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 4.0/5.5 MB 5.5 MB/s eta 0:00:01
#    ------------------------------- -------- 4.3/5.5 MB 5.4 MB/s eta 0:00:01
#    -------------------------------- ------- 4.4/5.5 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.7/5.5 MB 5.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.8/5.5 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.8/5.5 MB 4.7 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.5 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 5.5/5.5 MB 4.8 MB/s eta 0:00:00
# Downloading tensorflow_io_gcs_filesystem-0.31.0-cp311-cp311-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.5 MB 8.9 MB/s eta 0:00:01
#    -------------- ------------------------- 0.6/1.5 MB 7.0 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 7.0 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 4.9 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 4.9 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 3.6 MB/s eta 0:00:00
# Downloading termcolor-2.4.0-py3-none-any.whl (7.7 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading namex-0.0.8-py3-none-any.whl (5.8 kB)
# Downloading optree-0.11.0-cp311-cp311-win_amd64.whl (245 kB)
#    ---------------------------------------- 0.0/245.0 kB ? eta -:--:--
#    -------------------------------------- - 235.5/245.0 kB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 245.0/245.0 kB 3.0 MB/s eta 0:00:00
# Installing collected packages: namex, libclang, termcolor, tensorflow-io-gcs-filesystem, tensorboard-data-server, split-folders, optree, ml-dtypes, h5py, grpcio, google-pasta, gast, astunparse, tensorboard, keras, tensorflow-intel, tensorflow
#   Attempting uninstall: ml-dtypes
#     Found existing installation: ml-dtypes 0.4.0
#     Uninstalling ml-dtypes-0.4.0:
#       Successfully uninstalled ml-dtypes-0.4.0
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.9.0
#     Uninstalling h5py-3.9.0:
#       Successfully uninstalled h5py-3.9.0
# Successfully installed astunparse-1.6.3 gast-0.5.4 google-pasta-0.2.0 grpcio-1.64.1 h5py-3.11.0 keras-3.3.3 libclang-18.1.1 ml-dtypes-0.3.2 namex-0.0.8 optree-0.11.0 split-folders-0.5.1 tensorboard-2.16.2 tensorboard-data-server-0.7.2 tensorflow-2.16.1 tensorflow-intel-2.16.1 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import TensorBoard
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
    rescale=1./255,
)

val_datagen = ImageDataGenerator(rescale=1./255)

batch_size = 128

train_generator = train_datagen.flow_from_directory(
    './Split_CNN_data_96x96/train',
    target_size=(96, 96),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale'
)

validation_generator = val_datagen.flow_from_directory(
    './Split_CNN_data_96x96/val',
    target_size=(96, 96),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale'
)
# Out:
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.

# %%
pip install split-folders
# Out:
# Requirement already satisfied: split-folders in d:\anaconda\lib\site-packages (0.5.1)Note: you may need to restart the kernel to use updated packages.

# %%
import splitfolders
dr = 'SignImage48x48'
splitfolders.ratio(dr,"splitdataset48x48" ,ratio=(0.8,0.2))
# Out:
# Copying files: 1441 files [00:14, 100.70 files/s]

# %%
model.save('my_model.h5')

# %%
from keras.models import model_from_json
import cv2
import numpy as np

json_file = open("my_model.json", "r")
model_json = json_file.read()
json_file.close()
model = model_from_json(model_json)
model.load_weights("my_model.h5")

def extract_features(image):
    feature = np.array(image)
    feature = feature.reshape(1,48,48,1)
    return feature/255.0

cap = cv2.VideoCapture(0)
label = ['Hello', 'Super', 'Two', 'One', 'Three', 'blank']
while True:
    _,frame = cap.read()
    cv2.rectangle(frame,(0,40),(300,300),(0, 165, 255),1)
    cropframe=frame[40:300,0:300]
    cropframe=cv2.cvtColor(cropframe,cv2.COLOR_BGR2GRAY)
    cropframe = cv2.resize(cropframe,(48,48))
    cropframe = extract_features(cropframe)
    pred = model.predict(cropframe) 
    prediction_label = label[pred.argmax()]
    cv2.rectangle(frame, (0,0), (300, 40), (0, 165, 255), -1)
    if prediction_label == 'blank':
        cv2.putText(frame, " ", (10, 30),cv2.FONT_HERSHEY_SIMPLEX,1, (255, 255, 255),2,cv2.LINE_AA)
    else:
        accu = "{:.2f}".format(np.max(pred)*100)
        cv2.putText(frame, f'{prediction_label}  {accu}%', (10, 30),cv2.FONT_HERSHEY_SIMPLEX,1, (255, 255, 255),2,cv2.LINE_AA)
    cv2.imshow("output",frame)
    cv2.waitKey(27)
    
cap.release()
cv2.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
